# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/Roblox-Studio/blob/main/Scripts/Aula2_Aplicacao2_Ilha_do_Tesouro_Condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏝️ Aplicação 2 – Explorando a Ilha do Tesouro
# ## Roblox Studio + Google Colab
#
# ---
#
# # 🎯 Objetivos da Aula
#
# Nesta aula vamos utilizar estruturas condicionais para criar regras dentro do jogo.
#
# Os alunos irão construir:
#
# - ponte bloqueada
# - baú do tesouro
# - portal secreto
# - cristal de energia
# - sistema de medalhas
# - condição de vitória
#
# ---
#
# # 🧠 Conceitos Trabalhados
#
# ✔ IF
#
# ✔ ELSE
#
# ✔ ELSEIF
#
# ✔ Comparação de valores
#
# ✔ Tomada de decisão
#
# ✔ Regras de jogo

# %% [markdown]
# # 🎮 História da Aula
#
# O explorador desembarcou na Ilha do Tesouro.
#
# Para encontrar o tesouro ele precisará:
#
# 🗝️ Encontrar chaves
#
# ⚡ Coletar energia
#
# 🪙 Juntar moedas
#
# 🏆 Conquistar medalhas

# %% [markdown]
# # 🌉 Parte 1 – A Ponte da Floresta
#
# Existe uma ponte que leva até a floresta.
#
# Mas ela só pode ser atravessada por exploradores com energia suficiente.

# %%
local energia = 30

if energia >= 20 then
    print("Pode atravessar a ponte")
else
    print("Energia insuficiente")
end

# %% [markdown]
# # 🎯 Atividade 1
#
# Troque:
#
# ```lua
# local energia = 10
# ```
#
# O que acontece?

# %%
-- Teste aqui

# %% [markdown]
# # 🏆 Parte 2 – O Baú do Tesouro
#
# Você encontrou um baú escondido.
#
# Mas ele só abre se possuir moedas suficientes.

# %%
local moedas = 50

if moedas >= 50 then
    print("🏆 Baú Aberto!")
else
    print("Moedas insuficientes")
end

# %% [markdown]
# # 🎯 Atividade 2
#
# Troque:
#
# ```lua
# local moedas = 20
# ```
#
# Observe o resultado.

# %%
-- Teste aqui

# %% [markdown]
# # 🚪 Parte 3 – A Caverna Secreta
#
# Existe uma passagem secreta.
#
# Somente quem possui uma chave pode entrar.

# %%
local chave = true

if chave == true then
    print("🚪 Entrada Liberada")
else
    print("🔒 Entrada Bloqueada")
end

# %% [markdown]
# # 🎯 Atividade 3
#
# Troque:
#
# ```lua
# local chave = false
# ```
#
# Observe o resultado.

# %%
-- Teste aqui

# %% [markdown]
# # 🥇 Parte 4 – Sistema de Medalhas

# %%
local moedas = 80

if moedas >= 100 then
    print("🥇 Ouro")

elseif moedas >= 50 then
    print("🥈 Prata")

else
    print("🥉 Bronze")
end

# %% [markdown]
# # 🎯 Atividade 4
#
# Teste:
#
# ```lua
# local moedas = 120
# ```
#
# Depois:
#
# ```lua
# local moedas = 20
# ```

# %%
-- Teste aqui

# %% [markdown]
# # ⚡ Parte 5 – Cristal de Energia

# %%
local energia = 90

energia = energia + 20

if energia >= 100 then
    print("⚡ Energia Máxima")
else
    print("Energia: " .. energia)
end

# %% [markdown]
# # 🎯 Atividade 5
#
# Troque:
#
# ```lua
# local energia = 40
# ```

# %%
-- Teste aqui

# %% [markdown]
# # 🏆 Parte 6 – Encontrando o Tesouro

# %%
local pontos = 200

if pontos >= 200 then
    print("🏆 Você encontrou o Tesouro!")
end

# %% [markdown]
# # 🎯 Atividade 6
#
# Troque:
#
# ```lua
# local pontos = 150
# ```
#
# O que acontece?

# %%
-- Teste aqui

# %% [markdown]
# # 🎮 Aplicando no Roblox
#
# Agora vamos transformar essas regras em objetos reais do jogo.

# %% [markdown]
# # 🏆 Baú do Tesouro

# %%
local moedas = 50

script.Parent.Touched:Connect(function()

    local mensagem = Instance.new("Hint")

    if moedas >= 50 then
        mensagem.Text = "🏆 Baú Aberto!"
    else
        mensagem.Text = "Você precisa de mais moedas."
    end

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()

end)

# %% [markdown]
# # 🚪 Portal Secreto

# %%
local chave = true

script.Parent.Touched:Connect(function()

    local mensagem = Instance.new("Hint")

    if chave then
        mensagem.Text = "🚪 Portal Liberado"
    else
        mensagem.Text = "🔒 Portal Bloqueado"
    end

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()

end)

# %% [markdown]
# # ⚡ Cristal de Energia

# %%
local energia = 90

script.Parent.Touched:Connect(function()

    energia = energia + 20

    local mensagem = Instance.new("Hint")

    if energia >= 100 then
        mensagem.Text = "⚡ Energia Máxima"
    else
        mensagem.Text = "Energia: " .. energia
    end

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()

end)

# %% [markdown]
# # 📝 Lista de Exercícios
#
# ## Exercício 1
# Criar uma ponte que só libera passagem com energia maior que 20.
#
# ## Exercício 2
# Criar um baú que só abre com 50 moedas.
#
# ## Exercício 3
# Criar uma porta secreta usando uma chave.
#
# ## Exercício 4
# Criar um sistema de medalhas.
#
# ## Exercício 5
# Criar um cristal que mostra Energia Máxima.
#
# ## Exercício 6
# Criar uma condição de vitória.
#
# ## Exercício 7
# Criar um portal mágico.
#
# ## Exercício 8
# Criar um sistema de níveis.
#
# ## Exercício 9
# Criar uma regra para liberar uma fase.
#
# ## Exercício 10
# Crie uma regra própria para a Ilha do Tesouro.

# %%
-- Resolva os exercícios aqui

# %% [markdown]
# # 🏁 Desafio Final
#
# Monte uma área da Ilha contendo:
#
# ✅ um portal
#
# ✅ um baú
#
# ✅ uma condição de vitória
#
# ✅ um sistema de medalhas
#
# Utilizando:
#
# - if
# - else
# - elseif

# %%
-- Resolva o desafio aqui

# %% [markdown]
# # 🎯 Fechamento
#
# Hoje aprendemos a criar regras dentro dos jogos.
#
# Agora nosso explorador consegue:
#
# 🏆 Abrir baús
#
# 🚪 Acessar áreas secretas
#
# ⚡ Ganhar energia
#
# 🥇 Conquistar medalhas
#
# ---
#
# # 🚀 Próxima Aula
#
# 🔁 Estruturas de Repetição
#
# A Ilha do Tesouro começará a ganhar vida com objetos animados.
