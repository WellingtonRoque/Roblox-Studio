# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/Roblox-Studio/blob/main/Scripts/Aula1_Aplica%C3%A7%C3%A3o1_%E2%80%93_Sistema_do_Jogador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎮 Aula Aplicação 1 – Blocos Interativos
# ## Roblox Studio + Google Colab
#
# ---
#
# # 🎯 Objetivos da Aula
#
# Nesta aula vamos aplicar o conceito de variáveis utilizando blocos interativos no Roblox.
#
# Os alunos irão criar:
#
# - blocos que mudam de cor
# - blocos que mostram mensagens
# - blocos de pontos
# - blocos de dano
# - blocos de energia
#
# ---
#
# # 🧠 Conceitos Trabalhados
#
# ✔ Variáveis
# ✔ Eventos
# ✔ Alteração de valores
# ✔ Interação com objetos
# ✔ Scripts básicos

# %% [markdown]
# # 🎮 O que vamos criar?
#
# Vamos transformar nosso mapa em um laboratório de programação.
#
# O jogador poderá:
#
# - tocar blocos
# - ganhar pontos
# - perder vida
# - ganhar energia
# - mudar cores
#
# Tudo utilizando scripts simples.

# %% [markdown]
# # 🟦 Parte 1 – Bloco que Muda de Cor

# %%
script.Parent.Touched:Connect(function(hit)
    local personagem = hit.Parent

    if personagem:FindFirstChild("Humanoid") then
        script.Parent.Color = Color3.new(0, 1, 0)
    end
end)

# %% [markdown]
# # 🎯 Atividade 1
#
# Faça o bloco mudar para:
#
# - azul
# - vermelho
# - amarelo

# %% [markdown]
# # 🟨 Parte 2 – Bloco com Mensagem

# %%
script.Parent.Touched:Connect(function()
    print("Você encontrou um bloco especial!")
end)

# %% [markdown]
# # 🎯 Atividade 2
#
# Faça o bloco mostrar:
#
# - “Você ganhou pontos!”
# - “Energia aumentada!”
# - “Cuidado com a lava!”

# %% [markdown]
# # **🎮 Hint**
#
# Ele mostra mensagem no topo da tela.

# %%
script.Parent.Touched:Connect(function()
    local mensagem = Instance.new("Hint")

    mensagem.Text = "Você encontrou um bloco especial!"

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()
end)

# %% [markdown]
# 🎯 O QUE ACONTECE
#
# Quando o jogador toca:
#
# ✔ aparece mensagem na tela
#
# ✔ espera 3 segundos
#
# ✔ mensagem desaparece

# %% [markdown]
# # **🚀 IDEIAS QUE VOCÊ PODE FAZER**
#
# 🟩 Bloco verde
#
# Energia aumentada!
#
#
#
#
#
# 🟥 Bloco vermelho
#
# Cuidado! Você perdeu vida!
#
# 🟨 Moeda
#
# +10 pontos!

# %% [markdown]
# # 🟩 Parte 3 – Bloco de Pontos

# %%
local pontos = 0

script.Parent.Touched:Connect(function()
    pontos = pontos + 10

    print(pontos)
end)

# %% [markdown]
# # 🎯 Atividade 3
#
# Faça:
#
# - ganhar 50 pontos
# - ganhar mais 20
# - mostrar resultado

# %% [markdown]
# # **🎮 VERSÃO EVOLUÍDA - OBJETIVO**
#
# Quando o jogador tocar no bloco:
#
# ✔ ganhar pontos
#
# ✔ mostrar mensagem na tela
#
# ✔ mostrar quantos pontos ganhou

# %%
local pontos = 0

script.Parent.Touched:Connect(function()
    pontos = pontos + 10

    local mensagem = Instance.new("Hint")

    mensagem.Text = "Pontos: " .. pontos

    mensagem.Parent = game.Workspace

    wait(10)

    mensagem:Destroy()
end)

# %% [markdown]
# # 🟥 Parte 4 – Bloco de Dano

# %%
local vida = 100

script.Parent.Touched:Connect(function()
    vida = vida - 10

    print(vida)
end)

# %% [markdown]
# # 🎯 Atividade 4
#
# Faça:
#
# - perder 20 de vida
# - depois perder mais 30
# - mostrar resultado final

# %% [markdown]
# # **🟥 Evolução do Bloco de Dano – Sistema de Vida**
#
# Quando o jogador tocar no bloco:
#
# perderá vida
# o bloco ficará vermelho
# uma mensagem aparecerá na tela

# %%
local vida = 100

script.Parent.Touched:Connect(function()

    vida = vida - 10

    script.Parent.Color = Color3.new(1, 0, 0)

    local mensagem = Instance.new("Hint")

    mensagem.Text = "Vida: " .. vida

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()

end)

# %% [markdown]
# # 🟪 Parte 5 – Bloco de Energia

# %%
local energia = 50

script.Parent.Touched:Connect(function()
    energia = energia + 20

    print(energia)
end)

# %% [markdown]
# # 🎯 Atividade 5
#
# Faça:
#
# - ganhar 100 de energia
# - perder 40
# - mostrar resultado

# %% [markdown]
# # **🟩 Bloco de Energia – Power-up de Energia**
#
# Quando o jogador tocar no bloco:
#
# ganhará energia
#
# o bloco ficará verde
#
# uma mensagem aparecerá na tela

# %%
local energia = 50

script.Parent.Touched:Connect(function()

    energia = energia + 20

    script.Parent.Color = Color3.new(0, 1, 0)

    local mensagem = Instance.new("Hint")

    mensagem.Text = "Energia: " .. energia

    mensagem.Parent = game.Workspace

    wait(3)

    mensagem:Destroy()

end)

# %% [markdown]
# # 🎮 Organização do Mapa no Roblox
#
# Monte um mapa simples contendo:
#
# 🟦 blocos coloridos
# 🟨 blocos de pontos
# 🟥 blocos de dano
# 🟩 blocos de energia

# %% [markdown]
# # 🎯 Mini Desafio
#
# Crie um bloco que:
#
# - muda de cor
# - mostra mensagem
# - dá pontos
#
# Tudo ao mesmo tempo.

# %% [markdown]
# # 📝 Lista de Exercícios
#
# ---
#
# # 🎯 Exercício 1
#
# Crie um bloco azul ao tocar.
#
# ---
#
# # 🎯 Exercício 2
#
# Crie um bloco que mostre uma mensagem.
#
# ---
#
# # 🎯 Exercício 3
#
# Crie um bloco que dá 25 pontos.
#
# ---
#
# # 🎯 Exercício 4
#
# Crie um bloco que tira 15 de vida.
#
# ---
#
# # 🎯 Exercício 5
#
# Crie um bloco que aumenta energia.
#
# ---
#
# # 🎯 Exercício 6
#
# Crie um bloco que muda de cor e mostra mensagem.

# %% [markdown]
# # 🎯 Fechamento da Aula
#
# Hoje aprendemos:
#
# ✔ Eventos
# ✔ Variáveis
# ✔ Blocos interativos
# ✔ Alteração de cores
# ✔ Sistema de pontos
# ✔ Sistema de dano
